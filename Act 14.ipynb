# %% [markdown]
# <img src="http://sitemath.info/Images/politique1.jpg" >

# %% [markdown]
# <img src="http://sitemath.info/Images/politique2.jpg" >

# %% [markdown]
# <img src="http://sitemath.info/Images/politique3.jpg" >

# %%
def suites(n):
    a=40000
    b=60000
    for i in range(n):
        c=....        # on stocke une valeur pour l'utiliser non modifiée dans les calculs
        d=....        # on stocke une valeur pour l'utiliser non modifiée dans les calculs
        a=.....       #expression de la suite (an)
        b=.....       #expression de la suite (bn)
    return(a,b)
suites(10)   #le 10e terme

# %%
def tableautermes(n): 
    L1=[]
    L2=[]
    for i in range(...):
        a,b = suites(...)
        L1.append(a) #on stocke les  termes de la suite (an)
        L2.append(b) #on stocke les  termes de la suite (bn)
    return L1,L2 
tableautermes(10)

# %% [markdown]
# <img src="http://sitemath.info/Images/politique4.jpg" >

# %%
from random import*
import numpy as np
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.set_xlim(( 0, 100))
ax.set_ylim(( 0, 100000))
n=99
x=[p for p in range(n+1)]
y,z=.........     #En images les termes des suites (an) et (bn) pour les n premiers termes
plt.plot(x,y,'o')
plt.plot(x,z,'o')
plt.show()#on observe le comportement des termes de suites et les limites

# %% [markdown]
# <img src="http://sitemath.info/Images/politique5.jpg" >
